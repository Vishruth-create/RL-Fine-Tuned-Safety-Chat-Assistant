# %%
from getpass import getpass
from pathlib import Path
import json
import torch

from transformers import AutoTokenizer, AutoModelForCausalLM
import trlx
# Out:
# [2026-01-08 18:11:27,932] [WARNING] [real_accelerator.py:209:get_accelerator] Setting accelerator to CPU. If you have GPU or other accelerator, we were unable to detect it.
# /mnt/linuxdata/conda/envs/aiml/compiler_compat/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 7
#       4 import torch
#       6 from transformers import AutoTokenizer, AutoModelForCausalLM
# ----> 7 import trlx
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/trlx/__init__.py:1
# ----> 1 from .trlx import train
#       2 from .utils import logging
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/trlx/trlx.py:6
#       3 from typing import Callable, Dict, Iterable, List, Optional, Tuple
#       5 from trlx.data.configs import TRLConfig
# ----> 6 from trlx.data.default_configs import (
#       7     default_ilql_config,
#       8     default_ppo_config,
#       9     default_sft_config,
#      10 )
#      11 from trlx.utils import set_seed
#      12 from trlx.utils.loading import get_pipeline, get_trainer
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/trlx/data/default_configs.py:3
#       1 from pathlib import Path
# ----> 3 from trlx.models.modeling_ilql import ILQLConfig
#       4 from trlx.models.modeling_ppo import PPOConfig
#       5 from trlx.trainer.accelerate_sft_trainer import SFTConfig
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/trlx/models/modeling_ilql.py:8
#       5 from functools import reduce
#       6 from typing import Any, Optional, Tuple
# ----> 8 import deepspeed  # type: ignore
#       9 import numpy as np
#      10 import torch
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/deepspeed/__init__.py:30
#      28 from .accelerator import get_accelerator
#      29 from .constants import TORCH_DISTRIBUTED_DEFAULT_PORT
# ---> 30 from .runtime.engine import DeepSpeedEngine, DeepSpeedOptimizerCallable, DeepSpeedSchedulerCallable
#      31 from .runtime.engine import ADAM_OPTIMIZER, LAMB_OPTIMIZER, MUON_OPTIMIZER
#      32 from .runtime.hybrid_engine import DeepSpeedHybridEngine
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/deepspeed/runtime/engine.py:30
#      28 from .zero.offload_config import OffloadDeviceEnum, OffloadStateTypeEnum
#      29 from deepspeed.runtime.base_optimizer import ZeROOptimizer
# ---> 30 from deepspeed.runtime.zero.stage_1_and_2 import DeepSpeedZeroOptimizer
#      31 from deepspeed.runtime.zenflow.zenflow_stage_1_and_2 import ZenFlowZeroOptimizer
#      32 from deepspeed.runtime.zero.partition_parameters import ZeroParamStatus
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/deepspeed/runtime/zero/stage_1_and_2.py:36
#      34 from deepspeed.runtime.constants import PIPE_REPLICATED
#      35 from deepspeed.accelerator import get_accelerator
# ---> 36 from deepspeed.runtime.zero.muon.original_muon import muon_update
#      37 from deepspeed.checkpoint.constants import (DS_VERSION, GROUP_PADDINGS, PARTITION_COUNT, LOSS_SCALER,
#      38                                             SINGLE_PARTITION_OF_FP32_GROUPS, BASE_OPTIMIZER_STATE,
#      39                                             BASE_OPTIMIZER_STATE_STEP, CLIP_GRAD, ZERO_STAGE, PARAM_SLICE_MAPPINGS)
#      40 from deepspeed.utils import link_hp_params, lazy_init_hp_params_optimizer_state
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/deepspeed/runtime/zero/muon/original_muon.py:36
#      31 import deepspeed.comm as dist  # replace torch's distributed package with deepspeed.comm to resolve deepspeed check
#      32 from deepspeed.runtime import compiler
#      35 @compiler.compile()
# ---> 36 def zeropower_via_newtonschulz5(G, steps: int):
#      37     """
#      38     Newton-Schulz iteration to compute the zeroth power / orthogonalization of G. We opt to use a
#      39     quintic iteration whose coefficients are selected to maximize the slope at zero. For the purpose
#    (...)
#      44     performance at all relative to UV^T, where USV^T = G is the SVD.
#      45     """
#      46     assert G.ndim >= 2  # batched Muon implementation by @scottjmaddox, and put into practice in the record by @YouJiacheng
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/torch/__init__.py:2447, in compile(model, fullgraph, dynamic, backend, mode, options, disable)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:716, in optimize(*args, **kwargs)
#     711     raise RuntimeError(
#     712         "Graph breaks are not supported with aot compile. Please use torch.compile(fullgraph=True)."
#     713     )
#     715 if not callable(self.callback):
# --> 716     raise RuntimeError("aot compile requires a callable dynamo callback.")
#     718 assert self._hooks is not None
#     719 return aot_compile_fullgraph(
#     720     fn,
#     721     example_inputs,
#    (...)
#     725     ),
#     726 )
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:770, in _optimize(rebuild_ctx, backend, nopython, guard_export_fn, guard_fail_fn, disable, dynamic)
#     768 if config.debug_force_nested_calls:
#     769     fn = external_utils.wrap_inline(fn)
# --> 770 elif config.wrap_top_frame or (
#     771     (filename is None or trace_rules.check(fn))
#     772     and (
#     773         getattr(fn, "__name__", "")
#     774         not in ["_call_impl", "_wrapped_call_impl", "_lazy_forward"]
#     775     )
#     776     and filename not in DONT_WRAP_FILES
#     777 ):
#     778     # call to a builtin without a frame for us to capture
#     779     fn = external_utils.wrap_inline(fn)
#     781 def do_nothing(*arg: Any, **kwargs: Any) -> None:
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:669, in get_compiler_fn(compiler_fn)
#     659     self.prior_skip_guard_eval_unsafe = set_skip_guard_eval_unsafe(
#     660         _is_skip_guard_eval_unsafe_stance()
#     661     )
#     662     _maybe_set_eval_frame(_callback_from_stance(self.callback))
#     664 def __exit__(
#     665     self,
#     666     exc_type: Optional[type[BaseException]],
#     667     exc_val: Optional[BaseException],
#     668     exc_tb: Optional[types.TracebackType],
# --> 669 ) -> Optional[bool]:
#     670     assert self.prior is not unset
#     671     set_eval_frame(None)
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/torch/_dynamo/repro/after_dynamo.py:33
#      31 import torch
#      32 import torch.fx as fx
# ---> 33 from torch._dynamo.debug_utils import (
#      34     AccuracyError,
#      35     backend_accuracy_fails,
#      36     BUCK_CMD_PREFIX,
#      37     BuckTargetWriter,
#      38     extra_imports,
#      39     generate_config_string,
#      40     generate_env_vars_string,
#      41     helper_for_dump_minify,
#      42     InputReader,
#      43     InputWriter,
#      44     minifier_dir,
#      45     NNModuleToString,
#      46     NopInputReader,
#      47     run_fwd_maybe_bwd,
#      48     same_two_models,
#      49 )
#      50 from torch.fx.experimental.symbolic_shapes import fx_placeholder_targets
#      51 from torch.hub import tqdm
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/torch/_dynamo/debug_utils.py:43
#      41 import torch._subclasses.meta_utils
#      42 from torch import Tensor
# ---> 43 from torch._dynamo.testing import rand_strided
#      44 from torch._inductor.cpp_builder import normalize_path_separator
#      45 from torch._prims_common import is_float_dtype
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/torch/_dynamo/testing.py:33
#      31 import torch
#      32 from torch import fx
# ---> 33 from torch._dynamo.backends.debugging import aot_eager
#      34 from torch._dynamo.output_graph import OutputGraph
#      36 from . import config, eval_frame, optimize_assert, reset
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/torch/_dynamo/backends/debugging.py:40
#      37 from torch._functorch import config as functorch_config
#      38 from torch._functorch.compilers import ts_compile
# ---> 40 from .common import aot_autograd
#      41 from .registry import CompiledFn, CompilerFn, register_debug_backend as register_backend
#      44 if TYPE_CHECKING:
#
# File /mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/torch/_dynamo/backends/common.py:29
#      27 import torch
#      28 from torch._dynamo import disable
# ---> 29 from torch._dynamo.exc import TensorifyScalarRestartAnalysis
#      30 from torch._dynamo.utils import counters, defake, flatten_graph_inputs
#      31 from torch._functorch.aot_autograd import (
#      32     aot_module_simplified,
#      33     SerializableAOTDispatchCompiler,
#      34 )
#
# ImportError: cannot import name 'TensorifyScalarRestartAnalysis' from 'torch._dynamo.exc' (/mnt/linuxdata/conda/envs/aiml/lib/python3.10/site-packages/torch/_dynamo/exc.py)
